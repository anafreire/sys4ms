# %% [markdown]
# # Multiple Sclerosis: Data Analysis

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
from sklearn.metrics import average_precision_score
import os
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import scikitplot as skplt
from sklearn import metrics

# %% [markdown]
# # MAIN

# %%
# %matplotlib inline
# %run DataAcquisition.ipynb
# %run MissingData.ipynb
# %run PlottingResults.ipynb
# %run Training.ipynb

f = open("Report.txt", "a")

os.system("")

# Group of Different functions for different styles
class style():
    BLACK = '\033[30m'
    RED = '\033[31m'
    GREEN = '\033[32m'
    YELLOW = '\033[33m'
    BLUE = '\033[34m'
    MAGENTA = '\033[35m'
    CYAN = '\033[36m'
    WHITE = '\033[37m'
    UNDERLINE = '\033[4m'
    RESET = '\033[0m'

outcomes_file = '../Datos/Sys4MS_L.csv'
features_file = '../Datos/Sys4MS_DATA_LABELS_2020-01-25_2103.csv'
proteomics_file = '../datosproteomicagenetica/dropbox/matrix__ROWS_AllPhosphoCohortDonors__COLS_AllMeasuredPhosphosNormalizedBasalValue.csv'

outcomes_df = load_outcomes(outcomes_file)

demographics = ['Age', 'Gender']
clinical = ['MS Subtype', ' DIAGNOSIS 2017', 'Current Treatment', 'Treatment Line',
       'Disease duration', 'treatment_duration', 'time_since_last_relapse', 'EDSS', 'MSSS', 'ARMSS', 'T25WT (sec)',
       '9HPT', 'SDMT',
       'SL25', 'HCVA']
OCT = ['pRNFL', 'mRNFL',
       'Temporal pRNFL', 'TMV', 'TRT', 'GCIPL', 'INL', 'ORL']
mri = ['T2LC', 'T2LV', 'CELC', 'NBV', 'NWMV', 'NGMV']
citometry = ['%Total CD3+',
       'CD3+ CD4+', 'CD4+ CD25+ CD127- (Total Treg)',
       'CD45RA+ CD25low (Naive Treg)  ', 'CD45RA- CD25high (Effector Treg)',
       'CD3+ CD8+', 'CD3+ CD8+   CD28- CD127-', '%Total CD19+',
       'CD19+ CD24high CD38low (B Memory)', 'CD19+ CD24low CD38low (B Mature)',
       'CD19+ CD24high CD38 high (B Regulatory)',
       'CD19+ CD24- CD38high ( B Plasma)',
       'CD19+ CD24high CD38-(B Memory Atypical)', '%Total CD3- CD19-',
       'CD56+ CD16 low (CD56 dim)', 'CD56+ CD16 high  (CD 56 bright)',
       'CD56- CD16 + (CD56 neg)', '%Total CD3+ CD4+',
       'Th1 classic',
       'Th1 non classic',
       'Th17',
       'Th1/Th17']
msgb = ['MSGB non-HLA', 'MSGB HLA only', 'MSGB total']
proteomics = ['AKT1', 'AKTS1', 'CREB1', 'GSK3AB', 'HSPB1', 'IKBA', 'JUN', 'KS6B1',
       'LCK', 'MK_03_01', 'MK09', 'MK12', 'MP2K1', 'NRF2', 'P53', 'PGFRB',
       'PTN11', 'RS6', 'SRC', 'STAT1', 'STAT3', 'STAT5', 'STAT6', 'TF65',
       'WNK1']


feature_combinations = {"Dem + Cli": demographics + clinical, 
                        "Dem + Cli + OCT + MRI": demographics + clinical + OCT + mri,
                        "Dem + Cli + OCT + MRI + Citometry + Genetics": demographics + clinical + OCT + mri + citometry + msgb,
                        "Dem + Cli + OCT + MRI + Citometry + Genetics + Proteomics": demographics + clinical + OCT + mri + citometry + msgb + proteomics}

feature_acronym = {"Dem + Cli": "D+C", 
                        "Dem + Cli + OCT + MRI": "D+C+O+M",
                        "Dem + Cli + OCT + MRI + Citometry + Genetics": "D+C+O+M+C+G",
                        "Dem + Cli + OCT + MRI + Citometry + Genetics + Proteomics": "D+C+O+M+C+G+P"}

report = []

for outcome in outcomes_df: 
    
    print(style.GREEN + "\n*** OUTCOME = " + outcome + " ***\n")
    

    counter = 1
    
    predictions_roc = [] # for storing outcomes and predictions for each model
    predictions_roc_pca = [] # for storing outcomes and predictions for each model
    
    for combination in feature_combinations.values():
         
        df = load_features(features_file)
        if counter==4:
            proteomic_data = pd.read_csv(proteomics_file, encoding='ISO-8859-1', sep=',')
            proteomic_data['Unnamed: 0'] = proteomic_data['Unnamed: 0'].str.replace("-0", "-")
            proteomic_data = proteomic_data.rename(columns={"Unnamed: 0": "prot_id"})
            proteomic_data = proteomic_data.set_index('prot_id')
            proteomic_data.head(10)

            df = df.join(proteomic_data, how='inner')

        print (style.GREEN + list(feature_combinations.keys())[list(feature_combinations.values()).index(combination)])
        f.write("\n\n*** OUTCOME = " + outcome + " ***\n")
        f.write("*** FEATURES:" + list(feature_combinations.keys())[list(feature_combinations.values()).index(combination)] + " ***\n")
        df_combination = df[combination]
        df_outcome = join_outcome (df_combination, outcomes_df, outcome)

        print(style.BLUE + "*** Managing Missing Data:")
        dimension = 'columns' # or "rows"
        percentage = 10
        df_full = manage_missing_data (df_outcome, dimension, percentage)

        print(style.YELLOW + "*** Running Prediction Model: Random Forest with NO PCA ***")
        f.write ("\n Running Prediction Model: Random Forest with NO PCA ***\n")
        iterations = 50
        weight = True

        print("Size of data for prediction: ", df_full.shape)
        scores = RF_prediction (df_full, outcome, iterations, weight, 
                                list(feature_combinations.keys())[list(feature_combinations.values()).index(combination)])
        
        predictions_roc.append(scores[5]) # Storing best model
        
        f.write(scores[3])

        report.append([outcome, 
                       list(feature_combinations.keys())[list(feature_combinations.values()).index(combination)],
                       df_full.shape[0],
                       df_full[df_full[outcome]==0].shape[0], df_full[df_full[outcome]==1].shape[0],
                       '-', df_full.shape[1],
                       scores[0], scores[1], scores[2], scores[4]])

        print(style.MAGENTA + "*** Running Prediction Model: Random Forest with PCA ***")
        f.write("\n Running Prediction Model: Random Forest with PCA ***\n")
        scores = RF_prediction_PCA (df_full, outcome, iterations, weight)

        predictions_roc_pca.append(scores[6])
        
        f.write(scores[3])
  

        report.append([outcome, 
                       list(feature_combinations.keys())[list(feature_combinations.values()).index(combination)],
                       df_full.shape[0],
                       df_full[df_full[outcome]==0].shape[0], df_full[df_full[outcome]==1].shape[0],
                       'X', scores[4],
                       scores[0], scores[1], scores[2], scores[5]])

        counter+=1;
            
    combinations_roc = ["clin","clin+imaging","clin+imaging+gen","clin+imaging+omics"]
    fig = plt.figure(figsize=(3,5), dpi=300)
    #ROC Curve - NO PCA
    for i in range(0,4):
        
        fpr, tpr, thresh = metrics.roc_curve(predictions_roc[i][0], predictions_roc[i][1])
        #auc = metrics.roc_auc_score(predictions_roc[i][0], predictions_roc[i][1])
        plt.plot(fpr,tpr,label = combinations_roc[i])

    # Custom settings for the plot 
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('1-Specificity (False Positive Rate)')
    plt.ylabel('Sensitivity (True Positive Rate)')
    plt.title(outcome + ' - ROC')
    plt.legend(loc="lower right")
    plt.show()   # Display
    
    #Save to TIFF
    from PIL import Image
    from io import BytesIO

    # (1) save the image in memory in PNG format
    png1 = BytesIO()
    fig.savefig(png1, format='png',bbox_inches='tight')

    # (2) load this image into PIL
    png2 = Image.open(png1)

    # (3) save as TIFF
    name = outcome + "_ROC"
    png2.save(name + '.tiff')
    png1.close()
    png2.close()
    
    

report_df = pd.DataFrame(data=report, columns=['Outcome', 'Features', 'Num Patients', 'Class 0', 'Class 1', 
                                               'PCA', 'Num Features','Precision', 'Recall', 'F1', 'Valid'])
print(report_df.head(10))

report_df.to_csv('summary_table.csv', index=False)

f.flush()
f.close
# Out:
# *** OUTCOME = EDSS_change ***
#
# Index(['Age of MS Onset', 'Gender', 'Patient Excluded from the study?',
#        'Reason for excluding:', 'Age at inclusion', 'MS Subtype',
#        ' DIAGNOSIS 2017', 'Current Treatment', 'Treatment Line',
#        'Disease duration', 'EDSS', 'Was the EDSS confirmed?', 'uGMSSS',
#        'gARMSS', 'T25WT (sec)', '9HPT right hand (sec)',
#        '9HPT Left hand (sec)', 'SDMT', '2.5LCVA, right eye',
#        '2.5LCVA, left eye', 'HCVA LogMar Right eye', 'HCVA LogMar Left eye',
#        'pRNFL OD', 'pRNFL OS', 'mRNFL OD', 'mRNFL OS', 'Temporal pRNFL OD',
#        'Temporal pRNFL OS', 'TMV OD', 'TMV OS', 'TRT OD', 'TRT OS', 'GCIPL OD',
#        'GCIPL OS', 'INL OD ', 'INL OS', 'ORL OD', 'ORL OS', 'T2LC', 'T2LV',
#        'CELC', 'NBV', 'NWMV', 'NGMV', '%Total CD3+', 'CD3+ CD4+',
#        'CD4+ CD25+ CD127- (Total Treg)', 'CD45RA+ CD25low (Naive Treg)  ',
#        'CD45RA- CD25high (Effector Treg)', 'CD3+ CD8+',
#        'CD3+ CD8+   CD28- CD127-', '%Total CD19+',
#        'CD19+ CD24high CD38low (B Memory)', 'CD19+ CD24low CD38low (B Mature)',
#        'CD19+ CD24high CD38 high (B Regulatory)',
#        'CD19+ CD24- CD38high ( B Plasma)',
#        'CD19+ CD24high CD38-(B Memory Atypical)', '%Total CD3- CD19-',
#        'CD56+ CD16 low (CD56 dim)', 'CD56+ CD16 high  (CD 56 bright)',
#        'CD56- CD16 + (CD56 neg)', '%Total CD3+ CD4+',
#        'CD3+ CD4+ CCR6-  CD161- CXCR3+ (Th1 classic)',
#        'CD3+ CD4+ CCR6- CD161+ CXCR3+ (Th1 non classic)',
#        'CD3+ CD4+ CCR6+  CD161+ CXCR3- CCR4+  (Th17)',
#        'CD3+ CD4+ CCR6+  CD161+ CxCR3 high CCR4 low  (Th1/Th17)',
#        'MSGB non-HLA', 'MSGB HLA only', 'MSGB total', 'Age',
#        'treatment_duration', 'time_since_last_relapse'],
#       dtype='object')
# Size of data:  (328, 58)
# Dem + Cli
# Size of Data after joining with outcome:  (262, 24)
# *** Managing Missing Data:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   27.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# *** Running Prediction Model: Random Forest with NO PCA ***
# Size of data for prediction:  (262, 24)
# ***** Using number of CV: 10
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   31.8s finished
# ***** Best CV model: {'n_estimators': 123, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 5, 'class_weight': 'balanced', 'bootstrap': True}
# with CV score: 0.641
# Dem + Cli
#               precision    recall  f1-score   support
#
#            0       0.72      0.79      0.76       184
#            1       0.37      0.29      0.33        78
#
#     accuracy                           0.64       262
#    macro avg       0.55      0.54      0.54       262
# weighted avg       0.62      0.64      0.63       262
#
# *** Running Prediction Model: Random Forest with PCA ***
# ***** Features dimension before PCA: (262, 24)
# ***** Features dimension after PCA: (262, 2)
# ***** Using number of CV: 10
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 493 out of 500 | elapsed:   24.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   24.5s finished
# ***** Best CV model: {'n_estimators': 87, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 5, 'class_weight': 'balanced', 'bootstrap': True}
# with CV score: 0.630
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.74       184
#            1       0.37      0.36      0.37        78
#
#     accuracy                           0.63       262
#    macro avg       0.55      0.55      0.55       262
# weighted avg       0.63      0.63      0.63       262
#
# Index(['Age of MS Onset', 'Gender', 'Patient Excluded from the study?',
#        'Reason for excluding:', 'Age at inclusion', 'MS Subtype',
#        ' DIAGNOSIS 2017', 'Current Treatment', 'Treatment Line',
#        'Disease duration', 'EDSS', 'Was the EDSS confirmed?', 'uGMSSS',
#        'gARMSS', 'T25WT (sec)', '9HPT right hand (sec)',
#        '9HPT Left hand (sec)', 'SDMT', '2.5LCVA, right eye',
#        '2.5LCVA, left eye', 'HCVA LogMar Right eye', 'HCVA LogMar Left eye',
#        'pRNFL OD', 'pRNFL OS', 'mRNFL OD', 'mRNFL OS', 'Temporal pRNFL OD',
#        'Temporal pRNFL OS', 'TMV OD', 'TMV OS', 'TRT OD', 'TRT OS', 'GCIPL OD',
#        'GCIPL OS', 'INL OD ', 'INL OS', 'ORL OD', 'ORL OS', 'T2LC', 'T2LV',
#        'CELC', 'NBV', 'NWMV', 'NGMV', '%Total CD3+', 'CD3+ CD4+',
#        'CD4+ CD25+ CD127- (Total Treg)', 'CD45RA+ CD25low (Naive Treg)  ',
#        'CD45RA- CD25high (Effector Treg)', 'CD3+ CD8+',
#        'CD3+ CD8+   CD28- CD127-', '%Total CD19+',
#        'CD19+ CD24high CD38low (B Memory)', 'CD19+ CD24low CD38low (B Mature)',
#        'CD19+ CD24high CD38 high (B Regulatory)',
#        'CD19+ CD24- CD38high ( B Plasma)',
#        'CD19+ CD24high CD38-(B Memory Atypical)', '%Total CD3- CD19-',
#        'CD56+ CD16 low (CD56 dim)', 'CD56+ CD16 high  (CD 56 bright)',
#        'CD56- CD16 + (CD56 neg)', '%Total CD3+ CD4+',
#        'CD3+ CD4+ CCR6-  CD161- CXCR3+ (Th1 classic)',
#        'CD3+ CD4+ CCR6- CD161+ CXCR3+ (Th1 non classic)',
#        'CD3+ CD4+ CCR6+  CD161+ CXCR3- CCR4+  (Th17)',
#        'CD3+ CD4+ CCR6+  CD161+ CxCR3 high CCR4 low  (Th1/Th17)',
#        'MSGB non-HLA', 'MSGB HLA only', 'MSGB total', 'Age',
#        'treatment_duration', 'time_since_last_relapse'],
#       dtype='object')
# Size of data:  (328, 58)
# Dem + Cli + OCT + MRI
# Size of Data after joining with outcome:  (262, 38)
# *** Managing Missing Data:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 493 out of 500 | elapsed:   19.4s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   19.6s finished
# *** Running Prediction Model: Random Forest with NO PCA ***
# Size of data for prediction:  (262, 29)
# ***** Using number of CV: 10
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 493 out of 500 | elapsed:   33.7s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   34.2s finished
# ***** Best CV model: {'n_estimators': 87, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 5, 'class_weight': 'balanced', 'bootstrap': True}
# with CV score: 0.645
# Dem + Cli + OCT + MRI
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.76       184
#            1       0.35      0.23      0.28        78
#
#     accuracy                           0.65       262
#    macro avg       0.53      0.53      0.52       262
# weighted avg       0.61      0.65      0.62       262
#
# *** Running Prediction Model: Random Forest with PCA ***
# ***** Features dimension before PCA: (262, 29)
# ***** Features dimension after PCA: (262, 2)
# ***** Using number of CV: 10
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   40.0s finished
# ***** Best CV model: {'n_estimators': 65, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 5, 'class_weight': 'balanced', 'bootstrap': True}
# with CV score: 0.649
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.75       184
#            1       0.40      0.37      0.39        78
#
#     accuracy                           0.65       262
#    macro avg       0.57      0.57      0.57       262
# weighted avg       0.64      0.65      0.64       262
#
# Index(['Age of MS Onset', 'Gender', 'Patient Excluded from the study?',
#        'Reason for excluding:', 'Age at inclusion', 'MS Subtype',
#        ' DIAGNOSIS 2017', 'Current Treatment', 'Treatment Line',
#        'Disease duration', 'EDSS', 'Was the EDSS confirmed?', 'uGMSSS',
#        'gARMSS', 'T25WT (sec)', '9HPT right hand (sec)',
#        '9HPT Left hand (sec)', 'SDMT', '2.5LCVA, right eye',
#        '2.5LCVA, left eye', 'HCVA LogMar Right eye', 'HCVA LogMar Left eye',
#        'pRNFL OD', 'pRNFL OS', 'mRNFL OD', 'mRNFL OS', 'Temporal pRNFL OD',
#        'Temporal pRNFL OS', 'TMV OD', 'TMV OS', 'TRT OD', 'TRT OS', 'GCIPL OD',
#        'GCIPL OS', 'INL OD ', 'INL OS', 'ORL OD', 'ORL OS', 'T2LC', 'T2LV',
#        'CELC', 'NBV', 'NWMV', 'NGMV', '%Total CD3+', 'CD3+ CD4+',
#        'CD4+ CD25+ CD127- (Total Treg)', 'CD45RA+ CD25low (Naive Treg)  ',
#        'CD45RA- CD25high (Effector Treg)', 'CD3+ CD8+',
#        'CD3+ CD8+   CD28- CD127-', '%Total CD19+',
#        'CD19+ CD24high CD38low (B Memory)', 'CD19+ CD24low CD38low (B Mature)',
#        'CD19+ CD24high CD38 high (B Regulatory)',
#        'CD19+ CD24- CD38high ( B Plasma)',
#        'CD19+ CD24high CD38-(B Memory Atypical)', '%Total CD3- CD19-',
#        'CD56+ CD16 low (CD56 dim)', 'CD56+ CD16 high  (CD 56 bright)',
#        'CD56- CD16 + (CD56 neg)', '%Total CD3+ CD4+',
#        'CD3+ CD4+ CCR6-  CD161- CXCR3+ (Th1 classic)',
#        'CD3+ CD4+ CCR6- CD161+ CXCR3+ (Th1 non classic)',
#        'CD3+ CD4+ CCR6+  CD161+ CXCR3- CCR4+  (Th17)',
#        'CD3+ CD4+ CCR6+  CD161+ CxCR3 high CCR4 low  (Th1/Th17)',
#        'MSGB non-HLA', 'MSGB HLA only', 'MSGB total', 'Age',
#        'treatment_duration', 'time_since_last_relapse'],
#       dtype='object')
# Size of data:  (328, 58)
# Dem + Cli + OCT + MRI + Citometry + Genetics
# Size of Data after joining with outcome:  (262, 63)
# *** Managing Missing Data:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done 493 out of 500 | elapsed:   26.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   26.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# *** Running Prediction Model: Random Forest with NO PCA ***
# Size of data for prediction:  (262, 32)
# ***** Using number of CV: 10
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=-1)]: Done 493 out of 500 | elapsed:   29.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   29.9s finished
# ***** Best CV model: {'n_estimators': 131, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 5, 'class_weight': 'balanced', 'bootstrap': True}
# with CV score: 0.641
# Dem + Cli + OCT + MRI + Citometry + Genetics
#               precision    recall  f1-score   support
#
#            0       0.71      0.82      0.76       184
#            1       0.34      0.22      0.27        78
#
#     accuracy                           0.64       262
#    macro avg       0.53      0.52      0.51       262
# weighted avg       0.60      0.64      0.61       262
#
# *** Running Prediction Model: Random Forest with PCA ***
# ***** Features dimension before PCA: (262, 32)
# ***** Features dimension after PCA: (262, 2)
# ***** Using number of CV: 10
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    4.8s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-684f06dafb1b> in <module>
#     124         print(style.MAGENTA + "*** Running Prediction Model: Random Forest with PCA ***")
#     125         f.write("\n Running Prediction Model: Random Forest with PCA ***\n")
# --> 126         scores = RF_prediction_PCA (df_full, outcome, iterations, weight)
#     127
#     128         predictions_roc_pca.append(scores[6])
#
# <ipython-input-74-641b9172337a> in RF_prediction_PCA(df_full, outcome, iterations, weight)
#      17
#      18     print("***** Using number of CV:", cv_group)
# ---> 19     search_model = training(X_PCA, df_full[outcome], 50, cv=cv_group, weight = True)
#      20
#      21
#
# <ipython-input-74-4b01823c28f3> in training(features, target, n_iter, cv, weight)
#      47
#      48     # Train the model on training data
# ---> 49     trained_model = rf_random.fit(features, target);
#      50
#      51     # Look at parameters used by our current forest
#
# ~/opt/anaconda3/envs/p37/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/envs/p37/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/opt/anaconda3/envs/p37/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1529         evaluate_candidates(ParameterSampler(
#    1530             self.param_distributions, self.n_iter,
# -> 1531             random_state=self.random_state))
#
# ~/opt/anaconda3/envs/p37/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# ~/opt/anaconda3/envs/p37/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/envs/p37/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# ~/opt/anaconda3/envs/p37/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/opt/anaconda3/envs/p37/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/opt/anaconda3/envs/p37/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
